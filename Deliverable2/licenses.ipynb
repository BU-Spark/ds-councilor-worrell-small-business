# %%
#import the license datasets from the datasets/licenses folder
import pandas as pd

ote_licenses = pd.read_csv('../datasets/licenses/one_time_entertainment_licenses.csv')

spe_licenses = pd.read_csv('../datasets/licenses/special_event_licenses.csv')

ent_licenses = pd.read_csv('../datasets/licenses/entertainment_licenses.csv')

spe_licenses = spe_licenses[spe_licenses['City'] == 'Boston']
ent_licenses = ent_licenses[ent_licenses['city'] == 'Boston']
ote_licenses = ote_licenses[ote_licenses['city'] == 'Boston']
# Out:
#    App Number         App Name  Status Application Date Issued Date  \
# 0   PUB354144  Together Boston  Closed              NaN         NaN
# 7   PUB450642             void    Open              NaN         NaN
# 8   PUB450638         MA YOUTH    Open              NaN         NaN
# 9   PUB450616  City Hall Plaza    Open              NaN         NaN
# 10  PUB354146  Together Boston  Closed              NaN         NaN
#
#                                  Location Description Street Number  \
# 0   District Hall, 75 Nothern Ave, Seaport, Boston...            75
# 7                                                TEST             1
# 8       City Hall Plaza\r\nLogan Ferraro 978.835.4171             1
# 9       City Hall Plaza\r\nLogan Ferraro 978.835.4171             1
# 10  District Hall, 75 Nothern Ave, Seaport, Boston...            75
#
#    Street Name Street Suffix    City Zip Code  Start Date and Time  \
# 0     Northern            AV  Boston    02210  2014-05-15 00:00:00
# 7    City Hall            PZ  Boston    02201  2015-03-03 00:00:00
# 8    City Hall           PLZ  Boston    02108  2015-05-16 00:00:00
# 9    City Hall           PLZ  Boston    02108  2015-05-16 00:00:00
# 10    Northern            AV  Boston    02210  2014-05-15 00:00:00
#
#       End Date and Time
# 0   2014-05-18 00:00:00
# 7   2015-03-04 00:00:00
# 8   2015-05-16 00:00:00
# 9   2015-05-16 00:00:00
# 10  2014-05-18 00:00:00
