# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Input/business_list_district_categorized.csv")

df.shape
# Out:
# (4898, 24)

# %%
# remove all the inDis columns
df = df.drop(columns = ['inDis10'])

# save the dataframe to a csv file
df.to_csv("Input/business_list_district_categorized_clean.csv", index = False)

# %%
df.shape
# Out:
# (4898, 14)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                  0
# latitude                    0
# longitude                   0
# business_name               0
# street_address              0
# ZIP_code                    0
# NAICS_2017_6digit_code      0
# NAICS_2017_6digit_desc      0
# NAICS_2017_2digit_code      0
# NAICS_2017_2digit_desc      0
# estimated_employment        0
# employment_buckets          0
# mainstreet                  0
# district                  506
# dtype: int64

# %%
df['district'] = df['district'].fillna(3)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                0
# latitude                  0
# longitude                 0
# business_name             0
# street_address            0
# ZIP_code                  0
# NAICS_2017_6digit_code    0
# NAICS_2017_6digit_desc    0
# NAICS_2017_2digit_code    0
# NAICS_2017_2digit_desc    0
# estimated_employment      0
# employment_buckets        0
# mainstreet                0
# district                  0
# dtype: int64

# %%
df.to_csv("Input/business_list_district_categorized_clean.csv", index = False)

# %%
print(df['NAICS_2017_6digit_desc'].head())
# Out:
# 0                              Religious Organizations
# 1    All Other Miscellaneous Store Retailers (excep...
# 2    Financial Transactions Processing, Reserve, an...
# 3    Financial Transactions Processing, Reserve, an...
# 4    Financial Transactions Processing, Reserve, an...
# Name: NAICS_2017_6digit_desc, dtype: object

# %%
df['estimated_employment'] = df['estimated_employment'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 df['estimated_employment'] = df['estimated_employment'].astype(int)
#
# File ~/Documents/CS 506/project/venv/lib/python3.9/site-packages/pandas/core/generic.py:6245, in NDFrame.astype(self, dtype, copy, errors)
#    6238     results = [
#    6239         self.iloc[:, i].astype(dtype, copy=copy)
#    6240         for i in range(len(self.columns))
#    6241     ]
#    6243 else:
#    6244     # else, only a single dtype is given
# -> 6245     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6246     return self._constructor(new_data).__finalize__(self, method="astype")
#    6248 # GH 33113: handle empty frame or series
#
# File ~/Documents/CS 506/project/venv/lib/python3.9/site-packages/pandas/core/internals/managers.py:446, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df = df[df['NAICS_2017_6digit_desc'] != 'Undefined']

# %%
df.shape
# Out:
# (4898, 14)

# %%
# save to csv
df.to_csv("Input/business_list_district_categorized_clean.csv", index=False)

# %%
df.drop(df[df['NAICS_2017_6digit_desc'] == 'Undefined'].index, inplace=True)
df.shape
# Out:
# (4898, 14)

# %%
print(df['estimated_employment'].dtype)
# Out:
# object

# %%
df.head(4000)
# Out:
#       Unnamed: 0   latitude  longitude                       business_name  \
# 0            696  42.370221 -71.038709                      zion multi-svc
# 1            697  42.369918 -71.037917                             yah kid
# 2            698  42.369381 -71.039824        western union agent location
# 3            699  42.374317 -71.038620        western union agent location
# 4            700  42.375824 -71.039345        western union agent location
# ...          ...        ...        ...                                 ...
# 3995        4701  42.333894 -71.105502               rth community housing
# 3996        4702  42.335052 -71.109329     rth community center realty inc
# 3997        4703  42.330473 -71.097454  roxbury-parker saint church of god
# 3998        4704  42.335052 -71.109329          roxbury tenants of harvard
# 3999        4705  42.335907 -71.103455                romantique plaza llc
#
#          street_address  ZIP_code  NAICS_2017_6digit_code  \
# ...

# %%
df = pd.read_csv("Input/business_list_district_categorized_clean.csv")
df.head(5000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [91], line 1
# ----> 1 df = pd.read_csv("Input/business_list_district_categorized_clean.csv")
#       2 df.head(5000)
#
# File ~/Documents/CS 506/project/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Documents/CS 506/project/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
# ...

# %%
print(df[df['NAICS_2017_6digit_code'] == 0].shape[0])
# Out:
# 395

# %%
df.shape
# Out:
# (4898, 14)

# %%
df.drop(df[df['NAICS_2017_6digit_code'] == 0].index, inplace=True)

# %%
df.shape
# Out:
# (4503, 14)

# %%
df.head(5000)
# Out:
#       Unnamed: 0   latitude  longitude                 business_name  \
# 0            696  42.370221 -71.038709                zion multi-svc
# 1            697  42.369918 -71.037917                       yah kid
# 2            698  42.369381 -71.039824  western union agent location
# 3            699  42.374317 -71.038620  western union agent location
# 4            700  42.375824 -71.039345  western union agent location
# ...          ...        ...        ...                           ...
# 4893         691  42.353039 -71.130524                friendship bbq
# 4894         692  42.352800 -71.132800            florist in allston
# 4895         693  42.353039 -71.130524       china garden restaurant
# 4896         694  42.353348 -71.132988                  c fruit life
# 4897         695  42.353156 -71.131769            bab restaurant inc
#
#         street_address  ZIP_code  NAICS_2017_6digit_code  \
# 0       46 Maverick Sq      2128                  813110
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'latitude', 'longitude', 'business_name',
#        'street_address', 'ZIP_code', 'NAICS_2017_6digit_code',
#        'NAICS_2017_6digit_desc', 'NAICS_2017_2digit_code',
#        'NAICS_2017_2digit_desc', 'estimated_employment', 'employment_buckets',
#        'mainstreet', 'district'],
#       dtype='object')

# %%
# save to csv
df.to_csv("Input/Clean_District_Data/business_list_district_categorized_clean.csv", index=False)

# %%
df.shape
# Out:
# (4503, 14)

# %%
# remove the 711 index from the dataframe
df.drop(730, inplace=True)

# %%
df.shape
# Out:
# (4501, 14)

# %%
df.head(5000)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, latitude, longitude, business_name, street_address, ZIP_code, NAICS_2017_6digit_code, NAICS_2017_6digit_desc, NAICS_2017_2digit_code, NAICS_2017_2digit_desc, estimated_employment, employment_buckets, mainstreet, district]
# Index: []

# %%
df['estimated_employment'] = df['estimated_employment'].astype(int)

# %%
print(df['estimated_employment'].dtype)
# Out:
# int64

# %%
print(df['estimated_employment'].mean())
# Out:
# 10.506109753388136

# %%
print(type(df['employment_buckets']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['employment_buckets'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df['district'] = df['district'].astype(int)

# %%
# split the dataframe into separate dataframes by district
district_1 = df[df['district'] == 1]
district_2 = df[df['district'] == 2]
district_3 = df[df['district'] == 3]
district_4 = df[df['district'] == 4]
district_5 = df[df['district'] == 5]
district_6 = df[df['district'] == 6]
district_7 = df[df['district'] == 7]
district_8 = df[df['district'] == 8]
district_9 = df[df['district'] == 9]

# %%
# save each district dataframe to a csv
district_1.to_csv("Input/Clean_District_Data/district_1.csv", index=False)
district_2.to_csv("Input/Clean_District_Data/district_2.csv", index=False)
district_3.to_csv("Input/Clean_District_Data/district_3.csv", index=False)
district_4.to_csv("Input/Clean_District_Data/district_4.csv", index=False)
district_5.to_csv("Input/Clean_District_Data/district_5.csv", index=False)
district_6.to_csv("Input/Clean_District_Data/district_6.csv", index=False)
district_7.to_csv("Input/Clean_District_Data/district_7.csv", index=False)
district_8.to_csv("Input/Clean_District_Data/district_8.csv", index=False)
district_9.to_csv("Input/Clean_District_Data/district_9.csv", index=False)

# %% [markdown]
# If I want to figure out if businesses are over-represented in district 4, I have to understand how many businesses are in each district

# %%
df = pd.concat([district_1, district_2, district_3, district_4, district_5, district_6, district_7, district_8, district_9])

# %%
df.head(5000)
# Out:
#       Unnamed: 0   latitude  longitude                 business_name  \
# 0            696  42.370221 -71.038709                zion multi-svc
# 1            697  42.369918 -71.037917                       yah kid
# 2            698  42.369381 -71.039824  western union agent location
# 3            699  42.374317 -71.038620  western union agent location
# 4            700  42.375824 -71.039345  western union agent location
# ...          ...        ...        ...                           ...
# 4893         691  42.353039 -71.130524                friendship bbq
# 4894         692  42.352800 -71.132800            florist in allston
# 4895         693  42.353039 -71.130524       china garden restaurant
# 4896         694  42.353348 -71.132988                  c fruit life
# 4897         695  42.353156 -71.131769            bab restaurant inc
#
#         street_address  ZIP_code  NAICS_2017_6digit_code  \
# 0       46 Maverick Sq      2128                  813110
# ...

# %%
# use seaborn to make a bar plot of the number of businesses in each district, with a title, x label, y label, and a legend
import seaborn as sns
sns.set(style='whitegrid', context='talk', palette='Wistia_r')
sns.countplot(x='district', data=df, palette='Wistia_r')
plt.title("Number of Businesses in Each District")
plt.xlabel("District")
plt.ylabel("Number of Businesses")
# plt.legend(['District 1', 'District 2', 'District 3', 'District 4', 'District 5', 'District 6', 'District 7', 'District 8', 'District 9'])
# save the plot to a png file in the visualizations folder
plt.tight_layout()
plt.savefig("visualizations/number_of_businesses_in_each_district.jpeg", dpi=300)
plt.show()

# %% [markdown]
# District 4 has 390 businesses, it is most comparable in terms of business count to districts 3, 5, 7

# %%
# only keep rows where the employment_buckets column is 1-9 and 10-24
df = df[df['employment_buckets'].isin(['1-9', '10-24'])]

# %%
df.head(5000)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, latitude, longitude, business_name, street_address, ZIP_code, NAICS_2017_6digit_code, NAICS_2017_6digit_desc, NAICS_2017_2digit_code, NAICS_2017_2digit_desc, estimated_employment, employment_buckets, mainstreet, district]
# Index: []

# %%
df.to_csv("Input/Clean_District_Data/business_list_district_categorized_clean.csv", index=False)

# %%
df['small_business'] = df['estimated_employment'] < 25

# %%
df.head(5000)
# Out:
#       Unnamed: 0   latitude  longitude                 business_name  \
# 0            696  42.370221 -71.038709                zion multi-svc
# 1            697  42.369918 -71.037917                       yah kid
# 2            698  42.369381 -71.039824  western union agent location
# 3            699  42.374317 -71.038620  western union agent location
# 4            700  42.375824 -71.039345  western union agent location
# ...          ...        ...        ...                           ...
# 4893         691  42.353039 -71.130524                friendship bbq
# 4894         692  42.352800 -71.132800            florist in allston
# 4895         693  42.353039 -71.130524       china garden restaurant
# 4896         694  42.353348 -71.132988                  c fruit life
# 4897         695  42.353156 -71.131769            bab restaurant inc
#
#         street_address  ZIP_code  NAICS_2017_6digit_code  \
# 0       46 Maverick Sq      2128                  813110
# ...

# %%
# make a bar chart of the top 5 most common business types in each district
sns.countplot(y='NAICS_2017_6digit_desc', data=df, order=df['NAICS_2017_6digit_desc'].value_counts().iloc[:5].index)
plt.show()

# %%
small_businesses = df[df['small_business'] == True]

# %%
small_businesses.head(5000)
# Out:
#       Unnamed: 0   latitude  longitude                 business_name  \
# 0            696  42.370221 -71.038709                zion multi-svc
# 1            697  42.369918 -71.037917                       yah kid
# 2            698  42.369381 -71.039824  western union agent location
# 3            699  42.374317 -71.038620  western union agent location
# 4            700  42.375824 -71.039345  western union agent location
# ...          ...        ...        ...                           ...
# 4893         691  42.353039 -71.130524                friendship bbq
# 4894         692  42.352800 -71.132800            florist in allston
# 4895         693  42.353039 -71.130524       china garden restaurant
# 4896         694  42.353348 -71.132988                  c fruit life
# 4897         695  42.353156 -71.131769            bab restaurant inc
#
#         street_address  ZIP_code  NAICS_2017_6digit_code  \
# 0       46 Maverick Sq      2128                  813110
# ...

# %%
small_businesses.rename(columns={'NAICS_2017_6digit_desc': 'industry'}, inplace=True)
small_businesses.head(5000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 small_businesses.rename(columns={'NAICS_2017_6digit_desc': 'industry'}, inplace=True)
#       2 small_businesses.head(5000)
#
# NameError: name 'small_businesses' is not defined

# %%
# business_count = df.NAICS_2017_6digit_desc.value_counts()
# x_data = business_count.index
# y_data = business_count
# df_new = pd.DataFrame({'Business_type':x_data, "Count":y_data})
#
# plt.figure(figsize=(40,25))
# plt.bar(x_data[:25], y_data[:25])
# plt.xticks(fontsize = 18, rotation=90)
# plt.ylabel('Count')
# plt.title('Business Count by Business Type (TOP 25)', fontsize = 25)
# plt.tight_layout()
# plt.savefig('Business Type Count (Top 25).jpg')
# plt.show()

# group rows by district and industry

# %%
small_businesses.groupby(['district']).count()
# Out:
#           Unnamed: 0.1  Unnamed: 0  latitude  longitude  business_name  \
# district
# 1                  281         281       281        281            281
# 2                  657         657       657        657            657
# 3                  455         455       455        455            455
# 4                  373         373       373        373            373
# 5                  521         521       521        521            521
# 6                  807         807       807        807            807
# 7                  382         382       382        382            382
# 8                  194         194       194        194            194
# 9                  604         604       604        604            604
#
#           street_address  ZIP_code  NAICS_2017_6digit_code  industry  \
# district
# 1                    281       281                     281       281
# 2                    657       657                     657       657
# ...

# %%
small_businesses.to_csv("Input/small_businesses.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 small_businesses.to_csv("Input/small_businesses.csv")
#
# NameError: name 'small_businesses' is not defined

# %%
small_businesses = pd.read_csv("Input/small_businesses.csv")

# %%
print(small_businesses.groupby(['district']).count().mean())
# Out:
# Unnamed: 0.1              474.888889
# Unnamed: 0                474.888889
# latitude                  474.888889
# longitude                 474.888889
# business_name             474.888889
# street_address            474.888889
# ZIP_code                  474.888889
# NAICS_2017_6digit_code    474.888889
# industry                  474.888889
# NAICS_2017_2digit_code    474.888889
# NAICS_2017_2digit_desc    474.888889
# estimated_employment      474.888889
# employment_buckets        474.888889
# mainstreet                474.888889
# small_business            474.888889
# dtype: float64

# %%
print(small_businesses.groupby(['district']).count())
# Out:
#           Unnamed: 0.1  Unnamed: 0  latitude  longitude  business_name  \
# district
# 1                  281         281       281        281            281
# 2                  657         657       657        657            657
# 3                  455         455       455        455            455
# 4                  373         373       373        373            373
# 5                  521         521       521        521            521
# 6                  807         807       807        807            807
# 7                  382         382       382        382            382
# 8                  194         194       194        194            194
# 9                  604         604       604        604            604
#
#           street_address  ZIP_code  NAICS_2017_6digit_code  industry  \
# district
# 1                    281       281                     281       281
# 2                    657       657                     657       657
# ...

# %%
# use seaborn to make a bar plot of the number of businesses in each district, with a title, x label, y label, and a legend
import seaborn as sns
sns.set(style='whitegrid', context='talk', palette='Wistia_r')
sns.countplot(x='district', data=small_businesses, palette='Wistia_r')
plt.title("Number of Small Businesses in Each District")
plt.xlabel("District")
plt.ylabel("Number of Businesses")
# plt.legend(['District 1', 'District 2', 'District 3', 'District 4', 'District 5', 'District 6', 'District 7', 'District 8', 'District 9'])
# save the plot to a png file in the visualizations folder

# add a mean line to the plot on the y axis
plt.axhline(475, color='r', linestyle='dashed', linewidth=2)
plt.tight_layout()
#plt.savefig("visualizations/number_of_businesses_in_each_district.jpeg", dpi=300)
plt.show()

# %%
district_1 = pd.read_csv("Input/Clean_District_Data/district_1.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d1 = district_1.groupby(['NAICS_2017_6digit_desc'])

# count the number of businesses in each NAIICS_2017_6digit_desc

# make a bar plot of the top 5 NAICS_2017_6digit_desc in district 1 on the y axis and the count in each on the x axis
sns.set(style='whitegrid', context='talk', palette='Wistia_r')
sns.countplot(y='NAICS_2017_6digit_desc', data=district_1, palette='Wistia_r', order=grouped_d1.count().sort_values(by='business_name', ascending=False).head(5).index)
# Out:
# <AxesSubplot: xlabel='count', ylabel='NAICS_2017_6digit_desc'>

# %%
# open district 1 data
district_1 = pd.read_csv("Input/Clean_District_Data/district_1.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d1 = district_1.groupby(['NAICS_2017_6digit_desc'])

# count the number of businesses in each NAIICS_2017_6digit_desc

# make a bar plot of the top 5 NAICS_2017_6digit_desc in district 1 on the y axis and the count in each on the x axis
sns.set(style='whitegrid', context='talk', palette='Wistia_r')
sns.countplot(y='NAICS_2017_6digit_desc', data=district_1, palette='Wistia_r', order=grouped_d1.count().sort_values(by='business_name', ascending=False).head(5).index)

# do the same for each district and combine them into one plot
# district 2
district_2 = pd.read_csv("Input/Clean_District_Data/district_2.csv")
grouped_d2 = district_2.groupby(['NAICS_2017_6digit_desc'])
sns.countplot(y='NAICS_2017_6digit_desc', data=district_2, palette='Wistia_r', order=grouped_d2.count().sort_values(by='business_name', ascending=False).head(5).index)

# district 3
district_3 = pd.read_csv("Input/Clean_District_Data/district_3.csv")
grouped_d3 = district_3.groupby(['NAICS_2017_6digit_desc'])
sns.countplot(y='NAICS_2017_6digit_desc', data=district_3, palette='Wistia_r', order=grouped_d3.count().sort_values(by='business_name', ascending=False).head(5).index)

# district 4
district_4 = pd.read_csv("Input/Clean_District_Data/district_4.csv")
grouped_d4 = district_4.groupby(['NAICS_2017_6digit_desc'])
sns.countplot(y='NAICS_2017_6digit_desc', data=district_4, palette='Wistia_r', order=grouped_d4.count().sort_values(by='business_name', ascending=False).head(5).index)

# district 5
district_5 = pd.read_csv("Input/Clean_District_Data/district_5.csv")
grouped_d5 = district_5.groupby(['NAICS_2017_6digit_desc'])
sns.countplot(y='NAICS_2017_6digit_desc', data=district_5, palette='Wistia_r', order=grouped_d5.count().sort_values(by='business_name', ascending=False).head(5).index)

# district 6
district_6 = pd.read_csv("Input/Clean_District_Data/district_6.csv")
grouped_d6 = district_6.groupby(['NAICS_2017_6digit_desc'])
sns.countplot(y='NAICS_2017_6digit_desc', data=district_6, palette='Wistia_r', order=grouped_d6.count().sort_values(by='business_name', ascending=False).head(5).index)

# district 7
district_7 = pd.read_csv("Input/Clean_District_Data/district_7.csv")
grouped_d7 = district_7.groupby(['NAICS_2017_6digit_desc'])
sns.countplot(y='NAICS_2017_6digit_desc', data=district_7, palette='Wistia_r', order=grouped_d7.count().sort_values(by='business_name', ascending=False).head(5).index)

# district 8
district_8 = pd.read_csv("Input/Clean_District_Data/district_8.csv")
grouped_d8 = district_8.groupby(['NAICS_2017_6digit_desc'])
sns.countplot(y='NAICS_2017_6digit_desc', data=district_8, palette='Wistia_r', order=grouped_d8.count().sort_values(by='business_name', ascending=False).head(5).index)

# district 9
district_9 = pd.read_csv("Input/Clean_District_Data/district_9.csv")
grouped_d9 = district_9.groupby(['NAICS_2017_6digit_desc'])
sns.countplot(y='NAICS_2017_6digit_desc', data=district_9, palette='Wistia_r', order=grouped_d9.count().sort_values(by='business_name', ascending=False).head(5).index)

plt.title("Top 5 Industries in Each District")
plt.xlabel("Number of Businesses")
plt.ylabel("Industry")
plt.legend(['District 1', 'District 2', 'District 3', 'District 4', 'District 5', 'District 6', 'District 7', 'District 8', 'District 9'])
plt.tight_layout()
plt.savefig("visualizations/top_5_industries_in_each_district.jpeg", dpi=300)
plt.show()
# Out:
# /var/folders/2y/2xgh0bd95c19byky6srbz_sm0000gn/T/ipykernel_7404/3561855370.py:57: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# open district 1 data
district_1 = pd.read_csv("Input/Clean_District_Data/district_1.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d1 = district_1.groupby(['NAICS_2017_6digit_desc'])

# open district 2 data
district_2 = pd.read_csv("Input/Clean_District_Data/district_2.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d2 = district_2.groupby(['NAICS_2017_6digit_desc'])

# open district 3 data
district_3 = pd.read_csv("Input/Clean_District_Data/district_3.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d3 = district_3.groupby(['NAICS_2017_6digit_desc'])

# open district 4 data
district_4 = pd.read_csv("Input/Clean_District_Data/district_4.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d4 = district_4.groupby(['NAICS_2017_6digit_desc'])

# open district 5 data
district_5 = pd.read_csv("Input/Clean_District_Data/district_5.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d5 = district_5.groupby(['NAICS_2017_6digit_desc'])

# open district 6 data
district_6 = pd.read_csv("Input/Clean_District_Data/district_6.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d6 = district_6.groupby(['NAICS_2017_6digit_desc'])

# open district 7 data
district_7 = pd.read_csv("Input/Clean_District_Data/district_7.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d7 = district_7.groupby(['NAICS_2017_6digit_desc'])

# open district 8 data
district_8 = pd.read_csv("Input/Clean_District_Data/district_8.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d8 = district_8.groupby(['NAICS_2017_6digit_desc'])

# open district 9 data
district_9 = pd.read_csv("Input/Clean_District_Data/district_9.csv")
# group the rows by NAICS_2017_6digit_desc
grouped_d9 = district_9.groupby(['NAICS_2017_6digit_desc'])

# put all the grouped data into one list and make a bar plot of the top 5 industries in each district
grouped_districts = [grouped_d1, grouped_d2, grouped_d3, grouped_d4, grouped_d5, grouped_d6, grouped_d7, grouped_d8, grouped_d9]
fig, axes = plt.subplots(3, 3, figsize=(20, 20))
sns.set(style='whitegrid', context='talk', palette='Wistia_r')
for i in range(3):
    for j in range(3):
        sns.countplot(y='NAICS_2017_6digit_desc', data=grouped_districts[i*3+j].count().sort_values(by='business_name', ascending=False).head(5).index, ax=axes[i, j])
plt.tight_layout()
plt.savefig("visualizations/top_5_industries_in_each_district.jpeg", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [28], line 52
#      50 for i in range(3):
#      51     for j in range(3):
# ---> 52         sns.countplot(y='NAICS_2017_6digit_desc', data=grouped_districts[i*3+j].count().sort_values(by='business_name', ascending=False).head(5).index, ax=axes[i, j])
#      53 plt.tight_layout()
#      54 plt.savefig("visualizations/top_5_industries_in_each_district.jpeg", dpi=300)
#
# File ~/Documents/CS 506/project/venv/lib/python3.9/site-packages/seaborn/categorical.py:2942, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2939 elif x is not None and y is not None:
#    2940     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2942 plotter = _CountPlotter(
#    2943     x, y, hue, data, order, hue_order,
# ...

# %%
# district 4
district_4 = pd.read_csv("Input/Clean_District_Data/district_4.csv")
grouped_d4 = district_4.groupby(['NAICS_2017_6digit_desc'])
d4_plot = sns.countplot(y='NAICS_2017_6digit_desc', data=district_4, palette='Wistia_r', order=grouped_d4.count().sort_values(by='business_name', ascending=False).head(5).index)

# %%
df = pd.read_csv("Input/small_businesses.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   latitude  longitude  \
# 0             0         696  42.370221 -71.038709
# 1             1         697  42.369918 -71.037917
# 2             2         698  42.369381 -71.039824
# 3             3         699  42.374317 -71.038620
# 4             4         700  42.375824 -71.039345
#
#                   business_name   street_address  ZIP_code  \
# 0                zion multi-svc   46 Maverick Sq      2128
# 1                       yah kid  154 Maverick St      2128
# 2  western union agent location   14 Maverick Sq      2128
# 3  western union agent location     1 Central Sq      2128
# 4  western union agent location  238 Meridian St      2128
#
#    NAICS_2017_6digit_code                                           industry  \
# 0                  813110                            Religious Organizations
# 1                  453998  All Other Miscellaneous Store Retailers (excep...
# ...

# %%
import geopy.distance




business_types = df.industry.unique()
# find the average distance between each business type and save it to a dictionary
distance_dict = {}

# find the business types with a count less than 2
count_less_than_2 = []
for business_type in business_types:
    if df.industry.value_counts()[business_type] < 2:
        count_less_than_2.append(business_type)

# remove the business types with a count less than 2 from the distance_dict
for business_type in count_less_than_2:
    distance_dict.pop(business_type, None)
for business_type in business_types:
    # find the businesses of the current business type
    df_business = df[df.industry == business_type]
    # find the average distance between each business and save it to a dictionary
    distance_list = []
    for index, row in df_business.iterrows():
        # find the distance between the current business and all other businesses
        for index2, row2 in df_business.iterrows():
            if index != index2:
                distance = geopy.distance.distance((row['latitude'], row['longitude']), (row2['latitude'], row2['longitude'])).miles
                distance_list.append(distance)
    # find the average distance between businesses
    average_distance = sum(distance_list) / len(distance_list)
    distance_dict[business_type] = average_distance

# find the business type with the largest average distance
largest_distance = max(distance_dict.values())
largest_business_type = max(distance_dict, key=distance_dict.get)

# find the business type with the smallest average distance
smallest_distance = min(distance_dict.values())
smallest_business_type = min(distance_dict, key=distance_dict.get)

# print the results
print("The business type with the largest average distance between businesses is " + largest_business_type + " with an average distance of " + str(largest_distance) + " miles.")
print("The business type with the smallest average distance between businesses is " + smallest_business_type + " with an average distance of " + str(smallest_distance) + " miles.")

# make a bar graph of the business type and their average distance

# use seaborn to make a bar graph of the business type and their average distance, including an average line, with the average distance on the x axis and the business type on the y axis
sns.set_style("whitegrid")
sns.barplot(x=list(distance_dict.values()), y=list(distance_dict.keys()), color="blue")
plt.axvline(x=smallest_distance, color="red", linestyle="--")
plt.axvline(x=largest_distance, color="red", linestyle="--")
plt.xlabel("Average Distance Between Businesses (miles)")
plt.ylabel("Business Type")
plt.title("Average Distance Between Businesses by Business Type")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [40], line 31
#      29                 distance_list.append(distance)
#      30     # find the average distance between businesses
# ---> 31     average_distance = sum(distance_list) / len(distance_list)
#      32     distance_dict[business_type] = average_distance
#      34 # find the business type with the largest average distance
#
# ZeroDivisionError: division by zero

# %%
business_types = df.industry.unique()
# find the average distance between each business type and save it to a dictionary
distance_dict = {}


for business_type in business_types:
    # find the businesses of the current business type
    df_business = df[df.industry == business_type]
    # find the average distance between each business and save it to a dictionary
    distance_list = []
    for index, row in df_business.iterrows():
        # find the distance between the current business and all other businesses
        for index2, row2 in df_business.iterrows():
            if index != index2:
                distance = geopy.distance.distance((row['latitude'], row['longitude']), (row2['latitude'], row2['longitude'])).miles
                distance_list.append(distance)
    # find the average distance between businesses
    # if the len(distance_list) is 0, then the average distance is 0
    if len(distance_list) == 0:
        distance_dict[business_type] = 0
    else:
        average_distance = sum(distance_list) / len(distance_list)
        distance_dict[business_type] = average_distance

# find the business type with the largest average distance
largest_distance = max(distance_dict.values())
largest_business_type = max(distance_dict, key=distance_dict.get)

# find the business type with the smallest average distance
smallest_distance = min(distance_dict.values())
smallest_business_type = min(distance_dict, key=distance_dict.get)

# print the results
print("The business type with the largest average distance between businesses is " + largest_business_type + " with an average distance of " + str(largest_distance) + " miles.")
print("The business type with the smallest average distance between businesses is " + smallest_business_type + " with an average distance of " + str(smallest_distance) + " miles.")

# make a bar graph of the business type and their average distance

# use seaborn to make a bar graph of the business type and their average distance, including an average line, with the average distance on the x axis and the business type on the y axis
sns.set_style("whitegrid")
sns.barplot(x=list(distance_dict.values()), y=list(distance_dict.keys()), color="blue")
plt.axvline(x=smallest_distance, color="red", linestyle="--")
plt.axvline(x=largest_distance, color="red", linestyle="--")
plt.xlabel("Average Distance Between Businesses (miles)")
plt.ylabel("Business Type")
plt.title("Average Distance Between Businesses by Business Type")
plt.show()
# Out:
# The business type with the largest average distance between businesses is Bowling Centers with an average distance of 9.312662136363974 miles.
# The business type with the smallest average distance between businesses is Office Supplies and Stationery Stores with an average distance of 0 miles.

# %%
df_distance = pd.DataFrame.from_dict(distance_dict, orient='index', columns=['Average Distance Between Businesses (miles)'])
# plot the dataframe on a bar graph
df_distance.plot.barh()
plt.xlabel("Average Distance Between Businesses (miles)")
plt.ylabel("Business Type")
plt.title("Average Distance Between Businesses by Business Type")
plt.show()

# %%
# open the small_businesses.csv file as a dataframe
df = pd.read_csv("Input/small_businesses.csv")

# make a new dataframe from df of only district 4 businesses
df4 = df[df['district'] == 4]

# make a dataframe of the 10 most common business types in district 4
df4_top10 = df4['industry'].value_counts().head(10)

# make a dataframe of the 10 least common business types in district 4
df4_bottom10 = df4['industry'].value_counts().tail(10)

# %%
# print out the columns of df4_top10 and df4_bottom10
# print out the columns of df4_top10 and df4_bottom10
print(df4_top10.columns)
print(df4_bottom10.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [50], line 3
#       1 # print out the columns of df4_top10 and df4_bottom10
#       2 # print out the columns of df4_top10 and df4_bottom10
# ----> 3 print(df4_top10.columns)
#       4 print(df4_bottom10.columns)
#
# File ~/Documents/CS 506/project/venv/lib/python3.9/site-packages/pandas/core/generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
# what are the 10 most common business types in district 4?
df4['industry'].value_counts().head(10)
# Out:
# Full-Service Restaurants                                      33
# Beauty Salons                                                 23
# Wireless Telecommunications Carriers (except Satellite)       15
# Religious Organizations                                       15
# Other Social Advocacy Organizations                           14
# Supermarkets and Other Grocery (except Convenience) Stores    11
# Offices of Real Estate Agents and Brokers                     10
# Barber Shops                                                  10
# Other Individual and Family Services                           9
# Offices of Dentists                                            8
# Name: industry, dtype: int64

# %%
top10 = ['Restaurants', 'Retail Trade', 'Food Services and Drinking Places', 'Offices of Physicians (except Mental Health Specialists)', 'Offices of Dentists', 'Offices of Other Health Practitioners', 'Offices of Chiropractors', 'Offices of Optometrists', 'Offices of Mental Health Practitioners (except Physicians)', 'Offices of Podiatrists']

# %%
df = df[df['industry'].isin(top10)]
df.head(5000)
# Out:
#       Unnamed: 0.1  Unnamed: 0   latitude  longitude  \
# 39              43         739  42.375291 -71.038441
# 72              82         778  42.373793 -71.038801
# 86              96         792  42.371636 -71.038778
# 184            203         899  42.372155 -71.038812
# 186            206         902  42.370264 -71.038926
# ...            ...         ...        ...        ...
# 4148          4753         551  42.350769 -71.130981
# 4153          4759         557  42.350180 -71.130346
# 4232          4848         646  42.352800 -71.132800
# 4233          4849         647  42.350734 -71.131001
# 4235          4851         649  42.350386 -71.131634
#
#                       business_name         street_address  ZIP_code  \
# 39              smile dental center       14 Bennington St      2128
# 72         my dental east boston pc        151 Meridian St      2128
# 86               meridain dr dental         55 Meridian St      2128
# ...

# %%
# using the small_businesses dataframe, make a bar graph of the count of each business type, sorted by count
plt.figure(figsize=(30,10))
plt.bar(df['industry'].value_counts().index, df['industry'].value_counts().values)
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.title('Count of Businesses by Business Type')
# plt.savefig('Count of Businesses by Business Type.jpg')
plt.show()

# %%
# make a bar chart comparing the number of restaurants in district 4 to the number of restaurants in the rest of the city
plt.figure(figsize=(30,10))
plt.bar(['District 4', 'Rest of City'], [df4['industry'].value_counts()['Restaurants'], df['industry'].value_counts()['Restaurants']])
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.title('Count of Restaurants in District 4 vs. Rest of City')
# plt.savefig('Count of Restaurants in District 4 vs. Rest of City.jpg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/CS 506/project/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~/Documents/CS 506/project/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/CS 506/project/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Restaurants'
#
# ...

# %%
business_types = df4.industry.unique()
# find the average distance between each business type and save it to a dictionary
distance_dict = {}


for business_type in business_types:
    # find the businesses of the current business type
    df_business = df4[df4.industry == business_type]
    # find the average distance between each business and save it to a dictionary
    distance_list = []
    for index, row in df_business.iterrows():
        # find the distance between the current business and all other businesses
        for index2, row2 in df_business.iterrows():
            if index != index2:
                distance = geopy.distance.distance((row['latitude'], row['longitude']), (row2['latitude'], row2['longitude'])).miles
                distance_list.append(distance)
    # find the average distance between businesses
    # if the len(distance_list) is 0, then the average distance is 0
    if len(distance_list) == 0:
        distance_dict[business_type] = 0
    else:
        average_distance = sum(distance_list) / len(distance_list)
        distance_dict[business_type] = average_distance

# find the business type with the largest average distance
largest_distance = max(distance_dict.values())
largest_business_type = max(distance_dict, key=distance_dict.get)

# find the business type with the smallest average distance
smallest_distance = min(distance_dict.values())
smallest_business_type = min(distance_dict, key=distance_dict.get)

# print the results
print("The business type with the largest average distance between businesses is " + largest_business_type + " with an average distance of " + str(largest_distance) + " miles.")
print("The business type with the smallest average distance between businesses is " + smallest_business_type + " with an average distance of " + str(smallest_distance) + " miles.")

# make a bar graph of the business type and their average distance

# use seaborn to make a bar graph of the business type and their average distance, including an average line, with the average distance on the x axis and the business type on the y axis
sns.set_style("whitegrid")
sns.barplot(x=list(distance_dict.values()), y=list(distance_dict.keys()), color="blue")
plt.axvline(x=smallest_distance, color="red", linestyle="--")
plt.axvline(x=largest_distance, color="red", linestyle="--")
plt.xlabel("Average Distance Between Businesses (miles)")
plt.ylabel("Business Type")
plt.title("Average Distance Between Businesses by Business Type")
plt.show()
# Out:
# The business type with the largest average distance between businesses is General Freight Trucking, Local with an average distance of 1.970643804912998 miles.
# The business type with the smallest average distance between businesses is Radio Stations with an average distance of 0 miles.

# %%
df = pd.read_csv("Input/small_businesses.csv")

# %%
df = df[(df.industry == 'Full-Service Restaurants') | (df.industry == 'Beauty Salons') | (df.industry == 'Religious Organizations') | (df.industry == 'Wireless Telecommunications Carriers (except Satellite)') | (df.industry == 'Other Social Advocacy Organizations')]

# %%
df.head(5000)
# Out:
#       Unnamed: 0.1  Unnamed: 0   latitude  longitude  \
# 0                0         696  42.370221 -71.038709
# 13              15         711  42.370221 -71.038709
# 14              16         712  42.373487 -71.039272
# 19              21         717  42.376163 -71.039488
# 21              24         720  42.375986 -71.038950
# ...            ...         ...        ...        ...
# 4267          4890         688  42.352849 -71.132915
# 4268          4891         689  42.352169 -71.131601
# 4269          4893         691  42.353039 -71.130524
# 4271          4895         693  42.353039 -71.130524
# 4273          4897         695  42.353156 -71.131769
#
#                   business_name    street_address  ZIP_code  \
# 0                zion multi-svc    46 Maverick Sq      2128
# 13                unlimited pcs    46 Maverick Sq      2128
# 14           topacio restaurant   120 Meridian St      2128
# 19          the threading place   248 Meridian St      2128
# ...

# %%
df.to_csv("Input/small_businesses_top_5.csv", index=False)

# %%
# group by district and show the count of each industry per district
df.groupby(['district', 'industry']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='district'>

# %%
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# group by district and show the count of each industry per district, without the multiindex
df.groupby('district')['industry'].value_counts().unstack().plot(kind='bar', figsize=(20,10))
plt.title('Count of Businesses by Business Type and District')
plt.ylabel('Count')
plt.xlabel('District')
# plt.legend(loc='upper right')
# plt.savefig('Count of Businesses by Business Type and District.jpg')
plt.show()
