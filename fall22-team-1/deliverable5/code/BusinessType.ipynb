# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("MainStreets_Business_List.csv")
df
# Out:
#       Unnamed: 0   latitude  longitude  \
# 0              1  42.349398 -71.154065
# 1              2  42.350387 -71.165135
# 2              3  42.349219 -71.151769
# 3              4  42.349465 -71.153117
# 4              5  42.349453 -71.151543
# ...          ...        ...        ...
# 4933        4934  42.334142 -71.104168
# 4934        4935  42.332113 -71.099582
# 4935        4936  42.331603 -71.112383
# 4936        4937  42.333447 -71.105691
# 4937        4938  42.336170 -71.107132
#
#                                        business_name      street_address  \
# 0                            zisis convenience store   375 Washington St
# 1                                            ziggy's   583 Washington St
# 2                         zen zone acupuncture & spa   319 Washington St
# 3                                yes nails & spa inc       416 Market St
# 4                                            xfinity          12 Wirt St
# ...

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
# %matplotlib inline
world = geopandas.read_file('City_Council_Districts_View.geojson')

# %%
world
# Out:
#    OBJECTID_1  OBJECTID  DISTRICT    Shape_STAr     Shape_STLe  \
# 0           1         1         1  1.760562e+08  200651.489443
# 1           2         2         2  1.218674e+08  117132.199039
# 2           3         3         7  1.011971e+08   61019.579170
# 3           4         4         8  6.596258e+07   76621.126400
# 4           5         5         3  1.639291e+08  161426.282011
# 5           6         6         6  2.652834e+08  110999.737394
# 6           7         7         4  1.214597e+08   87092.598466
# 7           8         8         9  1.209243e+08   53571.779788
# 8           9         9         5  2.153749e+08  101357.952014
#
#                   Councilor                                          Webpage  \
# 0          Gabriela Coletta  https://www.boston.gov/departments/city-council
# 1                  Ed Flynn  https://www.boston.gov/departments/city-council
# 2  Tania Fernandes Anderson  https://www.boston.gov/departments/city-council
# ...

# %%
mattapan_business_type=df[df.mainstreet=="Mattapan Square"].NAICS_2017_2digit_desc.value_counts()
roslindale_business_type=df[df.mainstreet=="Roslindale Village"].NAICS_2017_2digit_desc.value_counts()
JP_business_type=df[df.mainstreet=="JP Centre/South"].NAICS_2017_2digit_desc.value_counts()

# %%
roslindale_business_type.values
# Out:
# array([46, 41, 39, 20, 19, 19, 13, 12,  7,  5,  4,  4,  3,  3,  3,  2,  1,
#         1])

# %%
mattapan_business_type.to_csv("mattapan_business_type.csv", index=True)
roslindale_business_type.to_csv("roslindale_business_type.csv", index=True)
JP_business_type.to_csv("JP_business_type.csv", index=True)

# %%
area_list = ["mattapan","roslindale","Jamaica Plain"]
df_list = [mattapan_business_type,roslindale_business_type,JP_business_type]
for i in range(3):
    visualization_business_type(df_list[i],area_list[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 3>()
#       2 df_list = [mattapan_business_type,roslindale_business_type,JP_business_type]
#       3 for i in range(3):
# ----> 4     visualization_business_type(df_list[i],area_list[i])
#
# Input In [39], in visualization_business_type(df, title)
#      13 y_data=df.values
#      14 x_data=df.index
# ---> 16 plt.barh(range(5), y_data, height=0.7, alpha=0.8) # 从下往上画
#      17 plt.yticks(range(5), x_data,fontproperties=my_font)
#      18 plt.xlim(30,47) #30~47，各1
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2403, in barh(y, width, height, left, align, **kwargs)
#    2401 @_copy_docstring_and_deprecators(Axes.barh)
#    2402 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2403     return gca().barh(
# ...

# %%
def visualization_business_type(df,title):
    y=df.values
    x=df.index
    fig = plt.figure(figsize=(15,4)) 
    
    x=roslindale_business_type.values
    y=roslindale_business_type.index
    plt.barh(y,x)
    plt.title('Store Inventory')
    plt.show()


    plt.show()

# %%
x=roslindale_business_type.values
y=roslindale_business_type.index
plt.barh(y,x)
plt.title('Business Type in Roslindale')
plt.show()

# %%
y_pos=roslindale_business_type.values
x_performance=roslindale_business_type.index
ax.barh(y_pos, performance, xerr=error, align='center')
# ax.set_yticks(y_pos)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 3>()
#       1 y_pos=roslindale_business_type.values
#       2 x_performance=roslindale_business_type.index
# ----> 3 ax.barh(y_pos, performance, xerr=error, align='center')
#       4 # ax.set_yticks(y_pos)
#       5 ax.invert_yaxis()  # labels read top-to-bottom
#
# NameError: name 'ax' is not defined

# %%
visualization_business_type(mattapan_business_type)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 visualization_business_type(mattapan_business_type)
#
# TypeError: visualization_business_type() missing 1 required positional argument: 'title'

# %%
#question2
mainstreet = df.dropna().mainstreet.unique()
for i in mainstreet:
    business_type_per_mainStreet = df[df.mainstreet==i].NAICS_2017_2digit_desc.value_counts()
    print(i)
    print(business_type_per_mainStreet[:3])
    print("==========================")
# Out:
# Brighton
# Other Services                      50
# Accommodation and Food Services     50
# Healthcare and Social Assistance    40
# Name: NAICS_2017_2digit_desc, dtype: int64
# ...
# Allston Village
# Accommodation and Food Services    105
# Retail Trade                        65
# Real Estate Rental and Leasing      52
# Name: NAICS_2017_2digit_desc, dtype: int64
# ...
# East Boston
# Retail Trade                       59
# Accommodation and Food Services    47
# Other Services                     33
# Name: NAICS_2017_2digit_desc, dtype: int64
# ...
# Chinatown
# Accommodation and Food Services    123
# Other Services                      67
# Undefined                           58
# Name: NAICS_2017_2digit_desc, dtype: int64
# ...
#
# 62    2
# Name: NAICS_2017_2digit_desc, dtype: int64
# ...
# Washington St Gateway
# Professional, Scientific, and Technical Services    49
# Other Services                                      46
# Retail Trade                                        46
# ...

# %%
#question1
count_business = df.dropna().NAICS_2017_2digit_desc.value_counts()
x_data = count_business.index
y_data = count_business
df_new = pd.DataFrame({'Business_type':x_data, "Count":y_data})
df_new = df_new.drop("62", axis=0)

# %%
#question1 visualization
y_data=df_new.Count.values
x_data=df_new.Business_type.values
fig = plt.figure(figsize=(15,4)) 

for i in range(len(x_data)):
    rect = plt.bar(x_data[i],y_data[i])
    plt.text(x_data[i], y_data[i], y_data[i], size=8, ha="center", va="bottom")
    plt.xticks(rotation=90)
plt.show()

# %%
# business type undefined
df[df.NAICS_2017_2digit_desc=="Other Services"]
# Out:
#       Unnamed: 0   latitude  longitude                       business_name  \
# 3              4  42.349465 -71.153117                 yes nails & spa inc
# 5              6  42.350165 -71.164769                          woof local
# 12            13  42.348919 -71.153648               wah foong electronics
# 16            17  42.349306 -71.154395              venetian beauty shoppe
# 23            24  42.349210 -71.152414                     thos upholstery
# ...          ...        ...        ...                                 ...
# 4882        4883  42.333328 -71.105972               carman's beauty salon
# 4913        4914  42.331779 -71.095940               boston cyclists union
# 4918        4919  42.333146 -71.100355                     boston basilica
# 4926        4927  42.333828 -71.103102                     american legion
# 4932        4933  42.331603 -71.112383  a-1 automatic transmission service
#
#           street_address  ZIP_code  NAICS_2017_6digit_code  \
# ...

# %%
df_new.to_csv("Business_type_count.csv",index=False)

# %%
count_business_2 = df.dropna().NAICS_2017_6digit_desc.value_counts()
df_new_2 = pd.DataFrame({'Business_type':count_business_2.index, "Count":count_business_2})
df_new_2
# Out:
#                                                                                         Business_type  \
# Full-Service Restaurants                                                     Full-Service Restaurants
#
# Offices of Real Estate Agents and Brokers                   Offices of Real Estate Agents and Brokers
# Beauty Salons                                                                           Beauty Salons
# Religious Organizations                                                       Religious Organizations
# ...                                                                                               ...
# Securities and Commodity Exchanges                                 Securities and Commodity Exchanges
# Charter Bus Industry                                                             Charter Bus Industry
# Toy and Hobby Goods and Supplies Merchant Whole...  Toy and Hobby Goods and Supplies Merchant Whol...
# ...

# %%
df
# Out:
#       Unnamed: 0   latitude  longitude  \
# 0              1  42.349398 -71.154065
# 1              2  42.350387 -71.165135
# 2              3  42.349219 -71.151769
# 3              4  42.349465 -71.153117
# 4              5  42.349453 -71.151543
# ...          ...        ...        ...
# 4933        4934  42.334142 -71.104168
# 4934        4935  42.332113 -71.099582
# 4935        4936  42.331603 -71.112383
# 4936        4937  42.333447 -71.105691
# 4937        4938  42.336170 -71.107132
#
#                                        business_name      street_address  \
# 0                            zisis convenience store   375 Washington St
# 1                                            ziggy's   583 Washington St
# 2                         zen zone acupuncture & spa   319 Washington St
# 3                                yes nails & spa inc       416 Market St
# 4                                            xfinity          12 Wirt St
# ...
