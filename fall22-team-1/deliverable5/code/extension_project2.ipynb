# %%
import pandas as pd

# %%
rf_df = pd.read_csv("relief_fund.csv")
Mattapan_rf = rf_df[rf_df["Neighborhood"]=="Mattapan"]
Dorchester_rf = rf_df[rf_df["Neighborhood"]=="Dorchester"]
Roslindale_rf = rf_df[rf_df["Neighborhood"]=="Roslindale"]
Jamaica_rf = rf_df[rf_df["Neighborhood"]=="Jamaica Plain"]

# %%
rf_count
# Out:
# [31, 306, 85, 117]

# %%
rf_count = [len(Mattapan_rf),len(Dorchester_rf),len(Roslindale_rf),len(Jamaica_rf)]
neighbourhood = ["Mattapan \n 31", "Dorchester \n 306", "Roslindale \n 85", "Jamaica Plain \n 117"]

import matplotlib.pyplot as plt
plt.pie(rf_count, labels=neighbourhood)
plt.title('Number of Small Businesses Recieved Small Business Relief Fund')
plt.tight_layout()
plt.show()

# %%
rf_df.Neighborhood
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 1849    West Roxbury
# 1850    West Roxbury
# 1851    West Roxbury
# 1852    West Roxbury
# 1853    West Roxbury
# Name: Neighborhood, Length: 1854, dtype: object
