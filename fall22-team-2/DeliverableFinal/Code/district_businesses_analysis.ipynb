# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import seaborn as sns
import numpy as np

# %% [markdown]
# # To get the businesses for each district
# Be careful with the filepaths--may need to change depending on where the files are saved.

# %%
# Set filepath for the shapefile
fp = "City_Council_Districts_View/city_council_districts.shp"
# Read shapefile using gpd.read_file()
map_df = gpd.read_file(fp)

# Set [map_df.DISTRICT == DISTRUCT_NUM]
# Can change the district_num to a district of choice
district_num = 4
d4 = map_df[map_df.DISTRICT == district_num]
d4 = d4[['DISTRICT', 'geometry']]

# Set coordinate system to the same !! very important!!!
d4 = d4.to_crs(epsg=4326)
business_df = pd.read_csv('businessList.csv') #print(business_df) ([4938 rows x 13 columns])
# Create geometry series
business_gp = gpd.GeoDataFrame(business_df, geometry=gpd.points_from_xy(business_df.longitude, business_df.latitude)) #print(business_gp) ([4938 rows x 14 columns])
business_gp = business_gp.set_crs(d4.crs, allow_override=True)
business_gp['district'] = ''
# Join 
datajoin4 = gpd.sjoin( business_gp, d4, how = 'inner', predicate = 'within')

# Export to csv file, can change file name (fn)
fn = "district4_businesses.csv"
datajoin4.to_csv(fn, index= False)

# %% [markdown]
# # Get the business types

# %%
#read in all the csv files for each district
df1 = pd.read_csv("ds-councilor-worrell-small-business/data/district1_businesses.csv")
df2 = pd.read_csv("ds-councilor-worrell-small-business/data/district2_businesses.csv")
df3 = pd.read_csv("ds-councilor-worrell-small-business/data/district3_businesses.csv")
df4 = pd.read_csv("ds-councilor-worrell-small-business/data/district4_businesses.csv")
df5 = pd.read_csv("ds-councilor-worrell-small-business/data/district5_businesses.csv")
df6 = pd.read_csv("ds-councilor-worrell-small-business/data/district6_businesses.csv")
df7 = pd.read_csv("ds-councilor-worrell-small-business/data/district7_businesses.csv")
df8 = pd.read_csv("ds-councilor-worrell-small-business/data/district8_businesses.csv")
df9 = pd.read_csv("ds-councilor-worrell-small-business/data/district9_businesses.csv")

#look at the business types based on 'NAICS_2017_2digit_desc' for each district
d1_businesstypeNAICS2digit = df1['NAICS_2017_2digit_desc'].value_counts(dropna = False)
d2_businesstypeNAICS2digit = df2['NAICS_2017_2digit_desc'].value_counts(dropna = False)
d3_businesstypeNAICS2digit = df3['NAICS_2017_2digit_desc'].value_counts(dropna = False)
d4_businesstypeNAICS2digit = df4['NAICS_2017_2digit_desc'].value_counts(dropna = False)
d5_businesstypeNAICS2digit = df5['NAICS_2017_2digit_desc'].value_counts(dropna = False)
d6_businesstypeNAICS2digit = df6['NAICS_2017_2digit_desc'].value_counts(dropna = False)
d7_businesstypeNAICS2digit = df7['NAICS_2017_2digit_desc'].value_counts(dropna = False)
d8_businesstypeNAICS2digit = df8['NAICS_2017_2digit_desc'].value_counts(dropna = False)
d9_businesstypeNAICS2digit = df9['NAICS_2017_2digit_desc'].value_counts(dropna = False)

# %%
#save results to csv file
d1_businesstypeNAICS2digit.to_csv("d1_businesstypeNAICS2digit.csv", index= False)
d2_businesstypeNAICS2digit.to_csv("d2_businesstypeNAICS2digit.csv", index= False)
d3_businesstypeNAICS2digit.to_csv("d3_businesstypeNAICS2digit.csv", index= False)
d4_businesstypeNAICS2digit.to_csv("d4_businesstypeNAICS2digit.csv", index= False)
d5_businesstypeNAICS2digit.to_csv("d5_businesstypeNAICS2digit.csv", index= False)
d6_businesstypeNAICS2digit.to_csv("d6_businesstypeNAICS2digit.csv", index= False)
d7_businesstypeNAICS2digit.to_csv("d7_businesstypeNAICS2digit.csv", index= False)
d8_businesstypeNAICS2digit.to_csv("d8_businesstypeNAICS2digit.csv", index= False)
d9_businesstypeNAICS2digit.to_csv("d9_businesstypeNAICS2digit.csv", index= False)

# %%
# read in the overal businesses
df = pd.read_csv("ds-councilor-worrell-small-business/data/businesses_districts.csv")

# %%
df = df[['NAICS_2017_2digit_desc', 'DISTRICT']]

# %%
#plot a bar graph of business types of all districts

fig = plt.figure(figsize= (50, 200))
ax = fig.add_subplot(1, 1, 1)
sns.set(font_scale=1.5)
sns.countplot(data= df, axes= ax, y= 'NAICS_2017_2digit_desc', hue= 'DISTRICT')
for container in ax.containers:
    ax.bar_label(container)
ax.tick_params(labelsize=20)
# ax.bar_label(ax.containers[0])

# %%
#save the bar graph
fig.savefig("businesstypes_alldistricts_bar.png")

# %% [markdown]
# ### Create bar graph of just district 4's business types

# %%
# read in file
df4 = pd.read_csv("ds-councilor-worrell-small-business/data/district4_businesses_regrouped.csv")

# %%
# clean
df4 = df4[['NAICS_2017_2digit_desc']]
businesstypeNAICS2digit = df4['NAICS_2017_2digit_desc'].value_counts(dropna = False)
df4 = df4.fillna('Undefined')

count = np.array(df4['NAICS_2017_2digit_desc'].value_counts(dropna = False))
types = df4['NAICS_2017_2digit_desc'].unique()

# plot
img = plt.rcdefaults()
fig, ax = plt.subplots()
bars = ax.barh(types, count)
ax.bar_label(bars)
ax.invert_yaxis()  # labels read vertically
ax.set_xlabel('Count')
ax.set_title('District 4 Business Types')

plt.savefig("district4_businesstypes.png")
plt.show()

# %%
fig.savefig("district4_businesses_regrouped_bar.png")

# %% [markdown]
# # District 4 Certified Businesses

# %%
# read in district4 's csv
d4_df = pd.read_csv("ds-councilor-worrell-small-business/data/district4_businesses.csv")

# %%
# copy 'business_name' under a new columned called 'company_name'
d4_df['company_name'] = d4_df['business_name']
d4_df.head(3)
# Out:
#     latitude  longitude                      business_name     street_address  \
# 0  42.311327 -71.080831                      wingz + tingz  388 Blue Hill Ave
# 1  42.305682 -71.081282             washington columbia li   95 Washington St
# 2  42.305682 -71.081282  washington columbia ii apartments   95 Washington St
#
#     zip  NAICS_2017_6digit_code                     NAICS_2017_6digit_desc  \
# 0  2121                  722511                   Full-Service Restaurants
# 1  2121                  531210  Offices of Real Estate Agents and Brokers
# 2  2121                       0                                        NaN
#
#    NAICS_2017_2digit_code           NAICS_2017_2digit_desc  \
# 0                      72  Accommodation and Food Services
# 1                      53   Real Estate Rental and Leasing
# 2                      99                        Undefined
#
#    estimated_employment employment_buckets  mainstreet  \
# 0                   5.0             1 to 9  Grove Hall
# 1                   3.0             1 to 9  Grove Hall
# 2                   5.0             1 to 9  Grove Hall
#
#                        geometry  district  index_right  DISTRICT  \
# 0  POINT (-71.080831 42.311327)       NaN            6         4
# 1  POINT (-71.081282 42.305682)       NaN            6         4
# 2  POINT (-71.081282 42.305682)       NaN            6         4
#
#                                 Name                       company_name
# 0                      wingz + tingz                      wingz + tingz
# 1             washington columbia li             washington columbia li
# 2  washington columbia ii apartments  washington columbia ii apartments

# %% [markdown]
# ### Certified Businesses

# %%
#certified business directory
cbd_df = pd.read_csv("ds-councilor-worrell-small-business/data/certifiedbusinessdirectory.csv")
cbd_df.head(3)
# Out:
#                              company_name  \
# 0                     9THAI EXPRESS , LLC
# 1  Turning On the Lights Global Institute
# 2     American Dream Home Care Agency LLC
#
#                                    services_provided mbe_wbe_cert  \
# 0                        FULL SERVICES OF RESTAURANT          MBE
# 1  Digital Coaching Service for Small Business Ow...         MWBE
# 2                Personal care attended , educations          WBE
#
#   small_local_cert veteran_cert sdo_certified city_registered  \
# 0              NaN          NaN            No              No
# 1              NaN          NaN            No              No
# 2              NaN          NaN            No              No
#
#                                              address      city state  ...  \
# 0  433 Cambridge Street, FIRST FLOOR., Boston, MA...    Boston    MA  ...
# 1         6 LIBERTY SQ, Suite 3013, Boston, MA 02109    Boston    MA  ...
# 2                 33 Dover Street, Brockton, MA 2301  Brockton    MA  ...
#
#   number_employees                      cob_category_codes1  \
# 0     Less than 10                                      NaN
# 1     Less than 10              TA - Training (see also ED)
# 2          11 - 20  AHS - Health Care (Providers, Services)
#
#                     cob_category_codes2 cob_category_codes3  \
# 0                                   NaN                 NaN
# 1  BU - Business Management Consultants      MK - Marketing
# 2                                   NaN                 NaN
#
#                                         naics_codes1  \
# 0                                                NaN
# 1  611430 - Professional and Management Developme...
# 2                 621610 - Home Health Care Services
#
#                               naics_codes2 naics_codes3  \
# 0                                      NaN          NaN
# 1  541613 - Marketing Consulting Services           NaN
# 2                                      NaN          NaN
#
#                                   unspsc_code1  \
# 0                                          NaN
# 1  86130000 - Specialized educational services
# 2     85100000 - Comprehensive health services
#
#                           unspsc_code2 unspsc_code3
# 0                                  NaN          NaN
# 1  86120000 - Educational institutions          NaN
# 2                                  NaN          NaN
#
# [3 rows x 30 columns]

# %%
#certified business directory
cbd_df = pd.read_csv("ds-councilor-worrell-small-business/data/Black&Brown-Owned_SelfIdentified_List.csv")
cbd_df.head()
# Out:
#                         Name                   Website   Contact phone  \
# 0              2 Dogs Treats       www.2dogstreats.com  (617) 286-4844
# 1                  1981andCo         www.1981andco.com  (617) 750-5896
# 2    A & M Home Services LLC                       NaN  (617) 697-2353
# 3  A Better Resolution, Inc.                       NaN  (617) 338-2022
# 4       A Gill of all Trades  www.agillofalltrades.com  (617) 922-7283
#
#                     Contact email Type of business  \
# 0            mike@2dogstreats.com           Online
# 1  1981andcophotography@gmail.com           Online
# 2     aandmhomeservices@yahoo.com              NaN
# 3     frank@abetterresolution.com              NaN
# 4    gmiller@agillofalltrades.com           Online
#
#                                              Address Neighborhood  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                     34 Vale Street          NaN
# 3  1313 Washington Street, Suite 519  Boston, MA ...          NaN
# 4                                                NaN          NaN
#
#                Business ownership      Business category Business sub type  \
# 0  Minority-owned,Immigrant-owned                 Retail               NaN
# 1      Black-owned,Minority-owned  Professional services               NaN
# 2                             NaN    Home-based services       Landscaping
# 3                             NaN         Arts & culture               NaN
# 4         Black-owned,Women-owned  Professional services               NaN
#
#                             Supplemental information
# 0  We are a Dorchester-based dog treat business f...
# 1  I do portrait work, art photography sessions, ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
#get street address from cbd_df['address']
def extract_streetaddress(df):
    splitA = df['Address'].str.split(',')
    df['street_address'] = splitA.str[0]
    return df

# %%
cbd_df = cbd_df.dropna(subset = ['Address'])

# %%
extract_streetaddress(cbd_df)
cbd_df.head(10)
# Out:
#                                     Name Website   Contact phone  \
# 2                A & M Home Services LLC     NaN  (617) 697-2353
# 3              A Better Resolution, Inc.     NaN  (617) 338-2022
# 5   A-Plus Welding and Engineering, Inc.     NaN  (857) 389-6243
# 6                 A.C.S. Mechanical, LLC     NaN  (781) 308-1151
# 7                    A.J. Williams Event     NaN  (617) 267-2244
# 8                 A.O. Security Services     NaN  (617) 970-6772
# 10                   Abel Floor Covering     NaN  (617) 288-0103
# 12       Above and Beyond Catering, Inc.     NaN  (617) 426-5999
# 15         Advertising Business Concepts     NaN  (617) 445-6171
# 16                           Advoqt, LLC     NaN  (617) 835-4525
#
#                   Contact email Type of business  \
# 2   aandmhomeservices@yahoo.com              NaN
# 3   frank@abetterresolution.com              NaN
# 5        weldboston54@gmail.com              NaN
# 6     acsmechanical@hotmail.com              NaN
# 7       aj@ajwilliamsevents.com              NaN
# 8            aossinc1@gmail.com              NaN
# 10        abelfloor@verizon.net              NaN
# 12            mark@aboveabc.com              NaN
# 15      abconcepts1@verizon.net              NaN
# 16            rm@advocatetg.com   Brick & mortar
#
#                                               Address Neighborhood  \
# 2                                      34 Vale Street          NaN
# 3   1313 Washington Street, Suite 519  Boston, MA ...          NaN
# 5               366 Walnut Avenue  Roxbury, MA 02119-          NaN
# 6    300 Washington Street, #3  Dorchester, MA 02121-          NaN
# 7      75 Newbury Street, 3rd Floor  Boston, MA 02116          NaN
# 8         2 Drayton Avenue  Dorchester, MA 02125-2403          NaN
# 10          410 Neponset Avenue  Dorchester, MA 02122          NaN
# 12               42 Plympton Street  Boston, MA 02118          NaN
# 15               8 Dennison Street  Roxbury, MA 02119          NaN
# 16      10 Guest Street, Suite 290  Boston, MA 02135-          NaN
#
#    Business ownership          Business category  Business sub type  \
# 2                 NaN        Home-based services        Landscaping
# 3                 NaN             Arts & culture                NaN
# 5      Certified MWBE               Construction         Contractor
# 6      Certified MWBE               Construction         Contractor
# 7      Certified MWBE      Professional services         Consulting
# 8                 NaN                      Other                NaN
# 10     Certified MWBE               Construction         Contractor
# 12                NaN  Restaurant & food service           Catering
# 15     Certified MWBE      Professional services  Printing services
# 16     Certified MWBE      Professional services         Consulting
#
#    Supplemental information                   street_address
# 2                       NaN                   34 Vale Street
# 3                       NaN           1313 Washington Street
# 5                       NaN       366 Walnut Avenue  Roxbury
# 6                       NaN            300 Washington Street
# 7                       NaN                75 Newbury Street
# 8                       NaN     2 Drayton Avenue  Dorchester
# 10                      NaN  410 Neponset Avenue  Dorchester
# 12                      NaN       42 Plympton Street  Boston
# 15                      NaN       8 Dennison Street  Roxbury
# 16                      NaN                  10 Guest Street

# %% [markdown]
# cbd_df_d4 = pd.merge(cbd_df, d4_df, how = "inner", on="street_address")
#
# merging on street address currently does not work because
# certifiedbusinessdirectory fully spells out street abbreviations eg: Quincy Street
# while d4 uses abbreviations eg: Quincy St
# so the dataframes are unable to be merged.
#
# Need to parse through and convert the Street to St / Avenue to Ave etc

# %%
cbd_df_d4 = pd.merge(cbd_df, d4_df, how = "inner", on="street_address")

cbd_df_d4.head()
# Out:
#                           Name_x                       Website  \
# 0  4 Corners Yoga + Wellness LLC  www.4cornersyogawellness.com
# 1             CKW Management Inc                           NaN
# 2             CKW Management Inc                           NaN
# 3             CKW Management Inc                           NaN
# 4             CKW Management Inc                           NaN
#
#     Contact phone                  Contact email Type of business  \
# 0  (617) 506-0519  info@4cornersyogawellness.com   Brick & mortar
# 1  (617) 237-0697     coleen@spotlightagency.net       Home-based
# 2  (617) 237-0697     coleen@spotlightagency.net       Home-based
# 3  (617) 237-0697     coleen@spotlightagency.net       Home-based
# 4  (617) 237-0697     coleen@spotlightagency.net       Home-based
#
#                                      Address Neighborhood  \
# 0                          336 Washington St   Dorchester
# 1  1773 Dorchester Ave, Dorchester, MA 02124   Dorchester
# 2  1773 Dorchester Ave, Dorchester, MA 02124   Dorchester
# 3  1773 Dorchester Ave, Dorchester, MA 02124   Dorchester
# 4  1773 Dorchester Ave, Dorchester, MA 02124   Dorchester
#
#                                   Business ownership     Business category  \
# 0                            Black-owned,Women-owned              Wellness
# 1  Black-owned,Certified MWBE,Immigrant-owned,Wom...  Professional service
# 2  Black-owned,Certified MWBE,Immigrant-owned,Wom...  Professional service
# 3  Black-owned,Certified MWBE,Immigrant-owned,Wom...  Professional service
# 4  Black-owned,Certified MWBE,Immigrant-owned,Wom...  Professional service
#
#         Business sub type  ... NAICS_2017_2digit_code  \
# 0          Massage, Yoga   ...                     61
# 1  Consulting, Coaching    ...                     23
# 2  Consulting, Coaching    ...                     54
# 3  Consulting, Coaching    ...                     81
# 4  Consulting, Coaching    ...                     81
#
#                              NAICS_2017_2digit_desc  estimated_employment  \
# 0                              Educational Services                   1.0
# 1                                      Construction                   2.0
# 2  Professional, Scientific, and Technical Services                   5.0
# 3                                    Other Services                   0.0
# 4                                    Other Services                   9.0
#
#    employment_buckets       mainstreet                      geometry district  \
# 0              1 to 9     Four Corners    POINT (-71.0737 42.299669)      NaN
# 1              1 to 9  Greater Ashmont  POINT (-71.063683 42.288998)      NaN
# 2              1 to 9  Greater Ashmont  POINT (-71.063683 42.288998)      NaN
# 3       Not Available  Greater Ashmont  POINT (-71.063683 42.288998)      NaN
# 4              1 to 9  Greater Ashmont  POINT (-71.063683 42.288998)      NaN
#
#    index_right  DISTRICT                          Name_y
# 0            6         4       4 corners yoga + wellness
# 1            6         4             star contracting co
# 2            6         4                     osa service
# 3            6         4  maat therapeutic solutions inc
# 4            6         4                jmn outreach inc
#
# [5 rows x 30 columns]

# %%
d4_df['Name']
# Out:
# 0                          wingz + tingz
# 1                 washington columbia li
# 2      washington columbia ii apartments
# 3                 washington columbia ii
# 4                           vip wireless
#                      ...
# 406                        ashmont grill
# 407                   ashmont cycles inc
# 408              aftab uddin biswas corp
# 409                     1943 dot ave llc
# 410                  american provisions
# Name: Name, Length: 411, dtype: object

# %%
cbd_df['Name'] = cbd_df['Name'].str.lower()

# %%
cbd_df_d4 = pd.merge(cbd_df, d4_df, how = "inner", on="Name")

cbd_df_d4.head()
# Out:
#                             Name                       Website  \
# 0  down home delivery & catering          downhomedelivery.com
# 1                 porta classica         www.portaclassica.com
# 2                     pure oasis  https://www.mypureoasis.com/
#
#     Contact phone              Contact email Type of business  \
# 0  (646) 226-0118         dhdc2008@gmail.com   Brick & mortar
# 1  (516) 830-5555  portaclassicama@gmail.com   Brick & mortar
# 2  (617) 420-6838                        NaN   Brick & mortar
#
#                                 Address Neighborhood  \
# 0  2 Bowdoin St., Dorchester, MA. 02124   Dorchester
# 1                     478 Blue Hill Ave   Dorchester
# 2                  430 Blue Hill Avenue   Dorchester
#
#                Business ownership          Business category  \
# 0         Black-owned,Women-owned  Restaurant & food service
# 1  Minority-owned,Immigrant-owned                     Retail
# 2                     Black-owned                     Retail
#
#                       Business sub type  ...  \
# 0  Delivery, Catering, Take-out, Other   ...
# 1                                   NaN  ...
# 2                                   NaN  ...
#
#                               NAICS_2017_6digit_desc  NAICS_2017_2digit_code  \
# 0                        Limited-Service Restaurants                      72
# 1                              Men's Clothing Stores                      44
# 2  All Other Miscellaneous Store Retailers (excep...                      45
#
#             NAICS_2017_2digit_desc  estimated_employment  employment_buckets  \
# 0  Accommodation and Food Services                   5.0              1 to 9
# 1                     Retail Trade                   7.0              1 to 9
# 2                     Retail Trade                   2.0              1 to 9
#
#      mainstreet                      geometry  district  index_right DISTRICT
# 0  Four Corners  POINT (-71.073321 42.299642)       NaN            6        4
# 1    Grove Hall  POINT (-71.083183 42.307953)       NaN            6        4
# 2    Grove Hall      POINT (-71.0828 42.3082)       NaN            6        4
#
# [3 rows x 29 columns]

# %%
replacers = {' St':' Street' , ' Ave': ' Avenue', ' Rd': ' Road'}

d4_testdf = d4_df.copy(deep = True)

d4_testdf['street_address'] = d4_testdf['street_address'].str.replace(" St", " Street")
d4_testdf['street_address'] = d4_testdf['street_address'].str.replace(" Ave", " Avenue")
d4_testdf['street_address'] = d4_testdf['street_address'].str.replace(" Rd", " Road")

d4_testdf['street_address']
# Out:
# 0        388 Blue Hill Avenue
# 1        95 Washington Street
# 2        95 Washington Street
# 3           102 Columbia Road
# 4        482 Blue Hill Avenue
#                 ...
# 406         555 Talbot Avenue
# 407    1977 Dorchester Avenue
# 408    1911 Dorchester Avenue
# 409    1943 Dorchester Avenue
# 410    1971 Dorchester Avenue
# Name: street_address, Length: 411, dtype: object

# %%
cbd_df_d4 = pd.merge(cbd_df, d4_testdf, how = "inner", on="street_address")

cbd_df_d4.head()
# Out:
#                 company_name_x  \
# 0  EMZ Rainbow Laundromat, LLC
# 1           OSA Services, Inc.
# 2           OSA Services, Inc.
# 3           OSA Services, Inc.
# 4           OSA Services, Inc.
#
#                                    services_provided mbe_wbe_cert  \
# 0                    Laundry services; laundromat             MBE
# 1  Accounting, bookkeeping, payroll, taxation ser...          MBE
# 2  Accounting, bookkeeping, payroll, taxation ser...          MBE
# 3  Accounting, bookkeeping, payroll, taxation ser...          MBE
# 4  Accounting, bookkeeping, payroll, taxation ser...          MBE
#
#   small_local_cert veteran_cert sdo_certified city_registered  \
# 0             SLBE          NaN            No             Yes
# 1             SLBE          NaN            No              No
# 2             SLBE          NaN            No              No
# 3             SLBE          NaN            No              No
# 4             SLBE          NaN            No              No
#
#                                              address        city state  ...  \
# 0              9 Bowdoin Street, Dorchester, MA 2124  Dorchester    MA  ...
# 1  1773 Dorchester Avenue, Suite 2A, Dorchester, ...  Dorchester    MA  ...
# 2  1773 Dorchester Avenue, Suite 2A, Dorchester, ...  Dorchester    MA  ...
# 3  1773 Dorchester Avenue, Suite 2A, Dorchester, ...  Dorchester    MA  ...
# 4  1773 Dorchester Avenue, Suite 2A, Dorchester, ...  Dorchester    MA  ...
#
#   NAICS_2017_2digit_code                            NAICS_2017_2digit_desc  \
# 0                     81                                    Other Services
# 1                     23                                      Construction
# 2                     54  Professional, Scientific, and Technical Services
# 3                     81                                    Other Services
# 4                     81                                    Other Services
#
#   estimated_employment employment_buckets       mainstreet  \
# 0                  1.0             1 to 9     Four Corners
# 1                  2.0             1 to 9  Greater Ashmont
# 2                  5.0             1 to 9  Greater Ashmont
# 3                  0.0      Not Available  Greater Ashmont
# 4                  9.0             1 to 9  Greater Ashmont
#
#                        geometry district index_right DISTRICT  \
# 0  POINT (-71.073051 42.299389)      NaN           6        4
# 1  POINT (-71.063683 42.288998)      NaN           6        4
# 2  POINT (-71.063683 42.288998)      NaN           6        4
# 3  POINT (-71.063683 42.288998)      NaN           6        4
# 4  POINT (-71.063683 42.288998)      NaN           6        4
#
#                    company_name_y
# 0          emz rainbow laundromat
# 1             star contracting co
# 2                     osa service
# 3  maat therapeutic solutions inc
# 4                jmn outreach inc
#
# [5 rows x 49 columns]

# %%
cbd_df_d4.to_csv("district4_certifiedbusiness.csv")
